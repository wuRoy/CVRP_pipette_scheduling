# %% [markdown]
# This notebook is used to reproduce the Figure 5 in the paper.

# %%
import numpy as np
import matplotlib.pyplot as plt
from ortools_solver import CVRP_solver
from utils import random_task_generation
from pipette_scheduler import calculate_D, calculate_S_E, calculate_D_prime,calculate_X
from baseline_methods import LAP, greedy
import pandas as pd

# %%
# define the types of labware
labware_list =[12,24,96,384]
# enumerate all the two combinations of the labware_list
labware_combinations = []
for i in range(len(labware_list)):
    for j in range(len(labware_list)):
        labware_combinations.append([labware_list[i], labware_list[j]])

# %%
# establish an empty dataframe to store the results
df = pd.DataFrame(columns=['source_labware', 'dest_labware', 'num_samples', 'repeat', 'row-major sorting','LAP', 'greedy','CVRP'])

# %%
np.random.seed(0)
for labware_combination in labware_combinations: 

    source_dim = labware_combination[0]
    dest_dim = labware_combination[1]
    print(f'source_dim={source_dim}, dest_dim={dest_dim}')
    # repeat the experiment 3 times
    for r in range(3):
        print('repeat:',r+1)
        stats = []
        for i in range(1, 11, 1):

            num_candidates = dest_dim * i 
            num_candidates = int(num_candidates)
            print(f'num_candidates={num_candidates}')
            a = random_task_generation(source_dim,dest_dim,num_candidates)
            jobs = np.argwhere(a)
            D_S = calculate_D(a.shape[0])
            D_D = calculate_D(a.shape[1])
            S, E, volumes = calculate_S_E(a)

            # calculate distance matrix for CVRP
            D_prime = calculate_D_prime(D_S, D_D, S, E, volumes, 1, 100, 1, 100)
            # solve the CVRP problem, the D_prime should be multiplied by 100 to avoid floating point issues
            CVRP_distance, CVRP_recorder = CVRP_solver(np.round(D_prime * 100).astype(np.int64), solving_time=20)
            # bring the VRP_distance to the original scale
            CVRP_distance = CVRP_distance / 100
            print(f'CVRP_distance: {CVRP_distance}')

            # calculate the cost of the row-major sorting
            # create a sequence of tasks
            tasks = np.array(range(jobs.shape[0]))
            tasks = tasks+1
            # if tasks.shape[0] %8 != 0, pad with -1
            if tasks.shape[0] %8 != 0:
                tasks = np.pad(tasks, (0, 8-tasks.shape[0]%8), 'constant', constant_values=-1)
            rms_seuqnece = tasks.reshape(-1, 8)
            t = calculate_X(rms_seuqnece)
            d = np.round(D_prime * 100)
            rms_distance = np.trace(np.dot(t.T, d))/100
            rms_distance = int(rms_distance)
            print(f'row-major sorting: {rms_distance}')
            
            # calculate the cost of the LAP
            index_matrix = np.zeros((source_dim,dest_dim))
            for j in range(jobs.shape[0]):
                index_matrix[jobs[j, 0], jobs[j, 1]] = j+1
            LAP_sequence = LAP(index_matrix)
            if LAP_sequence.shape[0] %8 != 0:
                LAP_sequence = np.pad(LAP_sequence, (0, 8-LAP_sequence.shape[0]%8), 'constant', constant_values=-1)
            LAP_sequence = LAP_sequence.reshape(-1, 8)
            t = calculate_X(LAP_sequence)
            LAP_distance = np.trace(np.dot(t.T, d))/100
            # change non_optimized_distance to integer
            LAP_distance = int(LAP_distance)
            print(f'LAP_distance: {LAP_distance}')

            # calculate the cost of the greedy optimized sequence
            greedy_optimized_sequence = greedy(jobs, d[1:,1:])
            if greedy_optimized_sequence.shape[0] %8 != 0:
                greedy_optimized_sequence = np.pad(greedy_optimized_sequence, (0, 8-greedy_optimized_sequence.shape[0]%8), 'constant', constant_values=-1)
            greedy_optimized_sequence = greedy_optimized_sequence.reshape(-1, 8)
            t = calculate_X(greedy_optimized_sequence)
            greedy_optimized_distance = np.trace(np.dot(t.T, d))/100
            print(f'greedy_optimized_distance: {greedy_optimized_distance}')
            # append the results to the df
            stats.append([source_dim, dest_dim, num_candidates, r+1, rms_distance, LAP_distance, greedy_optimized_distance, CVRP_distance])
        # convert the stats to the dataframe
        stats = pd.DataFrame(stats, columns=['source_labware', 'dest_labware', 'num_samples', 'repeat', 'row-major sorting','LAP', 'greedy','CVRP'])
        # append the stats to the df
        df = pd.concat([df, stats], ignore_index=True)
        print(df)
# save the results to a csv file
df.to_csv('results_different_labwares.csv', index=False)
# Out:
# source_dim=12, dest_dim=12
# repeat: 1
# num_candidates=12
# CVRP_distance: 25.77
# row-major sorting: 30
# LAP_distance: 28
# greedy_optimized_distance: 32.85
# num_candidates=24
# CVRP_distance: 43.84
# row-major sorting: 58
# LAP_distance: 53
# greedy_optimized_distance: 61.86
# num_candidates=36
# CVRP_distance: 69.3
# row-major sorting: 94
# LAP_distance: 87
# greedy_optimized_distance: 94.79
# num_candidates=48
# CVRP_distance: 77.28
# row-major sorting: 125
# LAP_distance: 99
# greedy_optimized_distance: 130.34
# num_candidates=60
# CVRP_distance: 96.21
# row-major sorting: 146
# LAP_distance: 129
# greedy_optimized_distance: 166.11
# num_candidates=72
# CVRP_distance: 111.71
# row-major sorting: 176
# LAP_distance: 155
# greedy_optimized_distance: 192.38
# num_candidates=84
# CVRP_distance: 128.94
# row-major sorting: 201
# LAP_distance: 186
# greedy_optimized_distance: 222.6
# num_candidates=96
# CVRP_distance: 138.63
# row-major sorting: 239
# LAP_distance: 195
# greedy_optimized_distance: 274.04
# num_candidates=108
# CVRP_distance: 154.84
# row-major sorting: 255
# LAP_distance: 209
# greedy_optimized_distance: 282.44
# num_candidates=120
# CVRP_distance: 162.09
# row-major sorting: 272
# LAP_distance: 221
# greedy_optimized_distance: 299.86
#   source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0             12           12          12      1                30   28
# 1             12           12          24      1                58   53
# 2             12           12          36      1                94   87
# 3             12           12          48      1               125   99
# 4             12           12          60      1               146  129
# 5             12           12          72      1               176  155
# 6             12           12          84      1               201  186
# 7             12           12          96      1               239  195
# 8             12           12         108      1               255  209
# 9             12           12         120      1               272  221
#
#    greedy    CVRP
# 0   32.85   25.77
# 1   61.86   43.84
# 2   94.79   69.30
# 3  130.34   77.28
# 4  166.11   96.21
# 5  192.38  111.71
# 6  222.60  128.94
# 7  274.04  138.63
# 8  282.44  154.84
# 9  299.86  162.09
# repeat: 2
# num_candidates=12
# /var/folders/rt/qt1716456c913tnjd66ntj8w0000gn/T/ipykernel_79490/962504384.py:71: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, stats], ignore_index=True)
# CVRP_distance: 23.87
# row-major sorting: 26
# LAP_distance: 25
# greedy_optimized_distance: 28.32
# num_candidates=24
# CVRP_distance: 52.74
# row-major sorting: 59
# LAP_distance: 60
# greedy_optimized_distance: 64.1
# num_candidates=36
# CVRP_distance: 68.77
# row-major sorting: 96
# LAP_distance: 86
# greedy_optimized_distance: 105.2
# num_candidates=48
# CVRP_distance: 83.33
# row-major sorting: 127
# LAP_distance: 106
# greedy_optimized_distance: 138.17
# num_candidates=60
# CVRP_distance: 95.5
# row-major sorting: 147
# LAP_distance: 127
# greedy_optimized_distance: 155.23
# num_candidates=72
# CVRP_distance: 112.84
# row-major sorting: 177
# LAP_distance: 150
# greedy_optimized_distance: 192.57
# num_candidates=84
# CVRP_distance: 124.33
# row-major sorting: 210
# LAP_distance: 166
# greedy_optimized_distance: 223.26
# num_candidates=96
# CVRP_distance: 140.51
# row-major sorting: 235
# LAP_distance: 189
# greedy_optimized_distance: 261.15
# num_candidates=108
# CVRP_distance: 149.52
# row-major sorting: 249
# LAP_distance: 200
# greedy_optimized_distance: 280.57
# num_candidates=120
# CVRP_distance: 171.87
# row-major sorting: 278
# LAP_distance: 237
# greedy_optimized_distance: 313.14
#    source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0              12           12          12      1                30   28
# 1              12           12          24      1                58   53
# 2              12           12          36      1                94   87
# 3              12           12          48      1               125   99
# 4              12           12          60      1               146  129
# 5              12           12          72      1               176  155
# 6              12           12          84      1               201  186
# 7              12           12          96      1               239  195
# 8              12           12         108      1               255  209
# 9              12           12         120      1               272  221
# 10             12           12          12      2                26   25
# 11             12           12          24      2                59   60
# 12             12           12          36      2                96   86
# 13             12           12          48      2               127  106
# 14             12           12          60      2               147  127
# 15             12           12          72      2               177  150
# 16             12           12          84      2               210  166
# 17             12           12          96      2               235  189
# 18             12           12         108      2               249  200
# 19             12           12         120      2               278  237
#
#     greedy    CVRP
# 0    32.85   25.77
# 1    61.86   43.84
# 2    94.79   69.30
# 3   130.34   77.28
# 4   166.11   96.21
# 5   192.38  111.71
# 6   222.60  128.94
# 7   274.04  138.63
# 8   282.44  154.84
# 9   299.86  162.09
# 10   28.32   23.87
# 11   64.10   52.74
# 12  105.20   68.77
# 13  138.17   83.33
# 14  155.23   95.50
# 15  192.57  112.84
# 16  223.26  124.33
# 17  261.15  140.51
# 18  280.57  149.52
# 19  313.14  171.87
# repeat: 3
# num_candidates=12
# CVRP_distance: 24.76
# row-major sorting: 32
# LAP_distance: 30
# greedy_optimized_distance: 31.53
# num_candidates=24
# CVRP_distance: 46.7
# row-major sorting: 60
# LAP_distance: 59
# greedy_optimized_distance: 67.51
# num_candidates=36
# CVRP_distance: 59.56
# row-major sorting: 90
# LAP_distance: 78
# greedy_optimized_distance: 96.48
# num_candidates=48
# CVRP_distance: 78.68
# row-major sorting: 122
# LAP_distance: 98
# greedy_optimized_distance: 126.81
# num_candidates=60
# CVRP_distance: 96.7
# row-major sorting: 164
# LAP_distance: 120
# greedy_optimized_distance: 175.4
# num_candidates=72
# CVRP_distance: 119.99
# row-major sorting: 190
# LAP_distance: 156
# greedy_optimized_distance: 209.11
# num_candidates=84
# CVRP_distance: 125.43
# row-major sorting: 205
# LAP_distance: 176
# greedy_optimized_distance: 224.7
# num_candidates=96
# CVRP_distance: 141.86
# row-major sorting: 222
# LAP_distance: 184
# greedy_optimized_distance: 242.0
# num_candidates=108
# CVRP_distance: 152.98
# row-major sorting: 265
# LAP_distance: 202
# greedy_optimized_distance: 288.9
# num_candidates=120
# CVRP_distance: 165.67
# row-major sorting: 273
# LAP_distance: 230
# greedy_optimized_distance: 329.93
#    source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0              12           12          12      1                30   28
# 1              12           12          24      1                58   53
# 2              12           12          36      1                94   87
# 3              12           12          48      1               125   99
# 4              12           12          60      1               146  129
# 5              12           12          72      1               176  155
# 6              12           12          84      1               201  186
# 7              12           12          96      1               239  195
# 8              12           12         108      1               255  209
# 9              12           12         120      1               272  221
# 10             12           12          12      2                26   25
# 11             12           12          24      2                59   60
# 12             12           12          36      2                96   86
# 13             12           12          48      2               127  106
# 14             12           12          60      2               147  127
# 15             12           12          72      2               177  150
# 16             12           12          84      2               210  166
# 17             12           12          96      2               235  189
# 18             12           12         108      2               249  200
# 19             12           12         120      2               278  237
# 20             12           12          12      3                32   30
# 21             12           12          24      3                60   59
# 22             12           12          36      3                90   78
# 23             12           12          48      3               122   98
# 24             12           12          60      3               164  120
# 25             12           12          72      3               190  156
# 26             12           12          84      3               205  176
# 27             12           12          96      3               222  184
# 28             12           12         108      3               265  202
# 29             12           12         120      3               273  230
#
#     greedy    CVRP
# 0    32.85   25.77
# 1    61.86   43.84
# 2    94.79   69.30
# 3   130.34   77.28
# 4   166.11   96.21
# 5   192.38  111.71
# 6   222.60  128.94
# 7   274.04  138.63
# 8   282.44  154.84
# 9   299.86  162.09
# 10   28.32   23.87
# 11   64.10   52.74
# 12  105.20   68.77
# 13  138.17   83.33
# 14  155.23   95.50
# 15  192.57  112.84
# 16  223.26  124.33
# 17  261.15  140.51
# 18  280.57  149.52
# 19  313.14  171.87
# 20   31.53   24.76
# 21   67.51   46.70
# 22   96.48   59.56
# 23  126.81   78.68
# 24  175.40   96.70
# 25  209.11  119.99
# 26  224.70  125.43
# 27  242.00  141.86
# 28  288.90  152.98
# 29  329.93  165.67
# source_dim=12, dest_dim=24
# repeat: 1
# num_candidates=24
# CVRP_distance: 51.9
# row-major sorting: 62
# LAP_distance: 59
# greedy_optimized_distance: 66.2
# num_candidates=48
# CVRP_distance: 86.01
# row-major sorting: 127
# LAP_distance: 105
# greedy_optimized_distance: 130.24
# num_candidates=72
# CVRP_distance: 125.82
# row-major sorting: 193
# LAP_distance: 158
# greedy_optimized_distance: 208.54
# num_candidates=96
# CVRP_distance: 162.3
# row-major sorting: 264
# LAP_distance: 200
# greedy_optimized_distance: 269.45
# num_candidates=120
# CVRP_distance: 184.09
# row-major sorting: 310
# LAP_distance: 235
# greedy_optimized_distance: 322.23
# num_candidates=144
# CVRP_distance: 216.67
# row-major sorting: 362
# LAP_distance: 293
# greedy_optimized_distance: 399.01
# num_candidates=168
# CVRP_distance: 249.1
# row-major sorting: 413
# LAP_distance: 309
# greedy_optimized_distance: 455.37
# num_candidates=192
# CVRP_distance: 277.21
# row-major sorting: 451
# LAP_distance: 346
# greedy_optimized_distance: 518.16
# num_candidates=216
# CVRP_distance: 306.72
# row-major sorting: 498
# LAP_distance: 392
# greedy_optimized_distance: 576.83
# num_candidates=240
# CVRP_distance: 337.75
# row-major sorting: 541
# LAP_distance: 413
# greedy_optimized_distance: 616.66
#    source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0              12           12          12      1                30   28
# 1              12           12          24      1                58   53
# 2              12           12          36      1                94   87
# 3              12           12          48      1               125   99
# 4              12           12          60      1               146  129
# 5              12           12          72      1               176  155
# 6              12           12          84      1               201  186
# 7              12           12          96      1               239  195
# 8              12           12         108      1               255  209
# 9              12           12         120      1               272  221
# 10             12           12          12      2                26   25
# 11             12           12          24      2                59   60
# 12             12           12          36      2                96   86
# 13             12           12          48      2               127  106
# 14             12           12          60      2               147  127
# 15             12           12          72      2               177  150
# 16             12           12          84      2               210  166
# 17             12           12          96      2               235  189
# 18             12           12         108      2               249  200
# 19             12           12         120      2               278  237
# 20             12           12          12      3                32   30
# 21             12           12          24      3                60   59
# 22             12           12          36      3                90   78
# 23             12           12          48      3               122   98
# 24             12           12          60      3               164  120
# 25             12           12          72      3               190  156
# 26             12           12          84      3               205  176
# 27             12           12          96      3               222  184
# 28             12           12         108      3               265  202
# 29             12           12         120      3               273  230
# 30             12           24          24      1                62   59
# 31             12           24          48      1               127  105
# 32             12           24          72      1               193  158
# 33             12           24          96      1               264  200
# 34             12           24         120      1               310  235
# 35             12           24         144      1               362  293
# 36             12           24         168      1               413  309
# 37             12           24         192      1               451  346
# 38             12           24         216      1               498  392
# 39             12           24         240      1               541  413
#
#     greedy    CVRP
# 0    32.85   25.77
# 1    61.86   43.84
# 2    94.79   69.30
# 3   130.34   77.28
# 4   166.11   96.21
# 5   192.38  111.71
# 6   222.60  128.94
# 7   274.04  138.63
# 8   282.44  154.84
# 9   299.86  162.09
# 10   28.32   23.87
# 11   64.10   52.74
# 12  105.20   68.77
# 13  138.17   83.33
# 14  155.23   95.50
# 15  192.57  112.84
# 16  223.26  124.33
# 17  261.15  140.51
# 18  280.57  149.52
# 19  313.14  171.87
# 20   31.53   24.76
# 21   67.51   46.70
# 22   96.48   59.56
# 23  126.81   78.68
# 24  175.40   96.70
# 25  209.11  119.99
# 26  224.70  125.43
# 27  242.00  141.86
# 28  288.90  152.98
# 29  329.93  165.67
# 30   66.20   51.90
# 31  130.24   86.01
# 32  208.54  125.82
# 33  269.45  162.30
# 34  322.23  184.09
# 35  399.01  216.67
# 36  455.37  249.10
# 37  518.16  277.21
# 38  576.83  306.72
# 39  616.66  337.75
# repeat: 2
# num_candidates=24
# CVRP_distance: 48.19
# row-major sorting: 59
# LAP_distance: 60
# greedy_optimized_distance: 60.26
# num_candidates=48
# CVRP_distance: 83.03
# row-major sorting: 126
# LAP_distance: 103
# greedy_optimized_distance: 122.68
# num_candidates=72
# CVRP_distance: 113.45
# row-major sorting: 184
# LAP_distance: 148
# greedy_optimized_distance: 198.94
# num_candidates=96
# CVRP_distance: 163.29
# row-major sorting: 253
# LAP_distance: 208
# greedy_optimized_distance: 272.48
# num_candidates=120
# CVRP_distance: 183.19
# row-major sorting: 305
# LAP_distance: 244
# greedy_optimized_distance: 322.5
# num_candidates=144
# CVRP_distance: 214.94
# row-major sorting: 352
# LAP_distance: 267
# greedy_optimized_distance: 384.55
# num_candidates=168
# CVRP_distance: 251.51
# row-major sorting: 410
# LAP_distance: 323
# greedy_optimized_distance: 446.87
# num_candidates=192
# CVRP_distance: 272.28
# row-major sorting: 453
# LAP_distance: 357
# greedy_optimized_distance: 512.71
# num_candidates=216
# CVRP_distance: 298.27
# row-major sorting: 490
# LAP_distance: 362
# greedy_optimized_distance: 563.32
# num_candidates=240
# CVRP_distance: 322.5
# row-major sorting: 529
# LAP_distance: 402
# greedy_optimized_distance: 630.71
#    source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0              12           12          12      1                30   28
# 1              12           12          24      1                58   53
# 2              12           12          36      1                94   87
# 3              12           12          48      1               125   99
# 4              12           12          60      1               146  129
# 5              12           12          72      1               176  155
# 6              12           12          84      1               201  186
# 7              12           12          96      1               239  195
# 8              12           12         108      1               255  209
# 9              12           12         120      1               272  221
# 10             12           12          12      2                26   25
# 11             12           12          24      2                59   60
# 12             12           12          36      2                96   86
# 13             12           12          48      2               127  106
# 14             12           12          60      2               147  127
# 15             12           12          72      2               177  150
# 16             12           12          84      2               210  166
# 17             12           12          96      2               235  189
# 18             12           12         108      2               249  200
# 19             12           12         120      2               278  237
# 20             12           12          12      3                32   30
# 21             12           12          24      3                60   59
# 22             12           12          36      3                90   78
# 23             12           12          48      3               122   98
# 24             12           12          60      3               164  120
# 25             12           12          72      3               190  156
# 26             12           12          84      3               205  176
# 27             12           12          96      3               222  184
# 28             12           12         108      3               265  202
# 29             12           12         120      3               273  230
# 30             12           24          24      1                62   59
# 31             12           24          48      1               127  105
# 32             12           24          72      1               193  158
# 33             12           24          96      1               264  200
# 34             12           24         120      1               310  235
# 35             12           24         144      1               362  293
# 36             12           24         168      1               413  309
# 37             12           24         192      1               451  346
# 38             12           24         216      1               498  392
# 39             12           24         240      1               541  413
# 40             12           24          24      2                59   60
# 41             12           24          48      2               126  103
# 42             12           24          72      2               184  148
# 43             12           24          96      2               253  208
# 44             12           24         120      2               305  244
# 45             12           24         144      2               352  267
# 46             12           24         168      2               410  323
# 47             12           24         192      2               453  357
# 48             12           24         216      2               490  362
# 49             12           24         240      2               529  402
#
#     greedy    CVRP
# 0    32.85   25.77
# 1    61.86   43.84
# 2    94.79   69.30
# 3   130.34   77.28
# 4   166.11   96.21
# 5   192.38  111.71
# 6   222.60  128.94
# 7   274.04  138.63
# 8   282.44  154.84
# 9   299.86  162.09
# 10   28.32   23.87
# 11   64.10   52.74
# 12  105.20   68.77
# 13  138.17   83.33
# 14  155.23   95.50
# 15  192.57  112.84
# 16  223.26  124.33
# 17  261.15  140.51
# 18  280.57  149.52
# 19  313.14  171.87
# 20   31.53   24.76
# 21   67.51   46.70
# 22   96.48   59.56
# 23  126.81   78.68
# 24  175.40   96.70
# 25  209.11  119.99
# 26  224.70  125.43
# 27  242.00  141.86
# 28  288.90  152.98
# 29  329.93  165.67
# 30   66.20   51.90
# 31  130.24   86.01
# 32  208.54  125.82
# 33  269.45  162.30
# 34  322.23  184.09
# 35  399.01  216.67
# 36  455.37  249.10
# 37  518.16  277.21
# 38  576.83  306.72
# 39  616.66  337.75
# 40   60.26   48.19
# 41  122.68   83.03
# 42  198.94  113.45
# 43  272.48  163.29
# 44  322.50  183.19
# 45  384.55  214.94
# 46  446.87  251.51
# 47  512.71  272.28
# 48  563.32  298.27
# 49  630.71  322.50
# repeat: 3
# num_candidates=24
# CVRP_distance: 49.0
# row-major sorting: 61
# LAP_distance: 58
# greedy_optimized_distance: 65.48
# num_candidates=48
# CVRP_distance: 87.14
# row-major sorting: 132
# LAP_distance: 110
# greedy_optimized_distance: 134.91
# num_candidates=72
# CVRP_distance: 129.56
# row-major sorting: 198
# LAP_distance: 168
# greedy_optimized_distance: 206.65
# num_candidates=96
# CVRP_distance: 146.39
# row-major sorting: 248
# LAP_distance: 190
# greedy_optimized_distance: 259.03
# num_candidates=120
# CVRP_distance: 179.91
# row-major sorting: 309
# LAP_distance: 235
# greedy_optimized_distance: 329.99
# num_candidates=144
# CVRP_distance: 221.78
# row-major sorting: 366
# LAP_distance: 280
# greedy_optimized_distance: 406.25
# num_candidates=168
# CVRP_distance: 244.03
# row-major sorting: 402
# LAP_distance: 308
# greedy_optimized_distance: 471.59
# num_candidates=192
# CVRP_distance: 277.95
# row-major sorting: 445
# LAP_distance: 366
# greedy_optimized_distance: 511.08
# num_candidates=216
# CVRP_distance: 316.5
# row-major sorting: 502
# LAP_distance: 393
# greedy_optimized_distance: 590.44
# num_candidates=240
# CVRP_distance: 316.55
# row-major sorting: 535
# LAP_distance: 431
# greedy_optimized_distance: 634.5
#    source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0              12           12          12      1                30   28
# 1              12           12          24      1                58   53
# 2              12           12          36      1                94   87
# 3              12           12          48      1               125   99
# 4              12           12          60      1               146  129
# 5              12           12          72      1               176  155
# 6              12           12          84      1               201  186
# 7              12           12          96      1               239  195
# 8              12           12         108      1               255  209
# 9              12           12         120      1               272  221
# 10             12           12          12      2                26   25
# 11             12           12          24      2                59   60
# 12             12           12          36      2                96   86
# 13             12           12          48      2               127  106
# 14             12           12          60      2               147  127
# 15             12           12          72      2               177  150
# 16             12           12          84      2               210  166
# 17             12           12          96      2               235  189
# 18             12           12         108      2               249  200
# 19             12           12         120      2               278  237
# 20             12           12          12      3                32   30
# 21             12           12          24      3                60   59
# 22             12           12          36      3                90   78
# 23             12           12          48      3               122   98
# 24             12           12          60      3               164  120
# 25             12           12          72      3               190  156
# 26             12           12          84      3               205  176
# 27             12           12          96      3               222  184
# 28             12           12         108      3               265  202
# 29             12           12         120      3               273  230
# 30             12           24          24      1                62   59
# 31             12           24          48      1               127  105
# 32             12           24          72      1               193  158
# 33             12           24          96      1               264  200
# 34             12           24         120      1               310  235
# 35             12           24         144      1               362  293
# 36             12           24         168      1               413  309
# 37             12           24         192      1               451  346
# 38             12           24         216      1               498  392
# 39             12           24         240      1               541  413
# 40             12           24          24      2                59   60
# 41             12           24          48      2               126  103
# 42             12           24          72      2               184  148
# 43             12           24          96      2               253  208
# 44             12           24         120      2               305  244
# 45             12           24         144      2               352  267
# 46             12           24         168      2               410  323
# 47             12           24         192      2               453  357
# 48             12           24         216      2               490  362
# 49             12           24         240      2               529  402
# 50             12           24          24      3                61   58
# 51             12           24          48      3               132  110
# 52             12           24          72      3               198  168
# 53             12           24          96      3               248  190
# 54             12           24         120      3               309  235
# 55             12           24         144      3               366  280
# 56             12           24         168      3               402  308
# 57             12           24         192      3               445  366
# 58             12           24         216      3               502  393
# 59             12           24         240      3               535  431
#
#     greedy    CVRP
# 0    32.85   25.77
# 1    61.86   43.84
# 2    94.79   69.30
# 3   130.34   77.28
# 4   166.11   96.21
# 5   192.38  111.71
# 6   222.60  128.94
# 7   274.04  138.63
# 8   282.44  154.84
# 9   299.86  162.09
# 10   28.32   23.87
# 11   64.10   52.74
# 12  105.20   68.77
# 13  138.17   83.33
# 14  155.23   95.50
# 15  192.57  112.84
# 16  223.26  124.33
# 17  261.15  140.51
# 18  280.57  149.52
# 19  313.14  171.87
# 20   31.53   24.76
# 21   67.51   46.70
# 22   96.48   59.56
# 23  126.81   78.68
# 24  175.40   96.70
# 25  209.11  119.99
# 26  224.70  125.43
# 27  242.00  141.86
# 28  288.90  152.98
# 29  329.93  165.67
# 30   66.20   51.90
# 31  130.24   86.01
# 32  208.54  125.82
# 33  269.45  162.30
# 34  322.23  184.09
# 35  399.01  216.67
# 36  455.37  249.10
# 37  518.16  277.21
# 38  576.83  306.72
# 39  616.66  337.75
# 40   60.26   48.19
# 41  122.68   83.03
# 42  198.94  113.45
# 43  272.48  163.29
# 44  322.50  183.19
# 45  384.55  214.94
# 46  446.87  251.51
# 47  512.71  272.28
# 48  563.32  298.27
# 49  630.71  322.50
# 50   65.48   49.00
# 51  134.91   87.14
# 52  206.65  129.56
# 53  259.03  146.39
# 54  329.99  179.91
# 55  406.25  221.78
# 56  471.59  244.03
# 57  511.08  277.95
# 58  590.44  316.50
# 59  634.50  316.55
# source_dim=12, dest_dim=96
# repeat: 1
# num_candidates=96
# CVRP_distance: 171.06
# row-major sorting: 270
# LAP_distance: 216
# greedy_optimized_distance: 256.37
# num_candidates=192
# CVRP_distance: 338.06
# row-major sorting: 525
# LAP_distance: 425
# greedy_optimized_distance: 544.66
# num_candidates=288
# CVRP_distance: 476.58
# row-major sorting: 788
# LAP_distance: 601
# greedy_optimized_distance: 822.97
# num_candidates=384
# CVRP_distance: 613.33
# row-major sorting: 983
# LAP_distance: 756
# greedy_optimized_distance: 1071.64
# num_candidates=480
# CVRP_distance: 790.41
# row-major sorting: 1248
# LAP_distance: 907
# greedy_optimized_distance: 1331.96
# num_candidates=576
# CVRP_distance: 884.68
# row-major sorting: 1389
# LAP_distance: 1037
# greedy_optimized_distance: 1569.48
# num_candidates=672
# CVRP_distance: 1031.37
# row-major sorting: 1614
# LAP_distance: 1160
# greedy_optimized_distance: 1829.54
# num_candidates=768
# CVRP_distance: 1156.39
# row-major sorting: 1793
# LAP_distance: 1359
# greedy_optimized_distance: 2086.51
# num_candidates=864
# CVRP_distance: 1243.66
# row-major sorting: 1888
# LAP_distance: 1395
# greedy_optimized_distance: 2221.94
# num_candidates=960
# CVRP_distance: 1362.49
# row-major sorting: 2053
# LAP_distance: 1493
# greedy_optimized_distance: 2440.34
#    source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0              12           12          12      1                30    28
# 1              12           12          24      1                58    53
# 2              12           12          36      1                94    87
# 3              12           12          48      1               125    99
# 4              12           12          60      1               146   129
# ..            ...          ...         ...    ...               ...   ...
# 65             12           96         576      1              1389  1037
# 66             12           96         672      1              1614  1160
# 67             12           96         768      1              1793  1359
# 68             12           96         864      1              1888  1395
# 69             12           96         960      1              2053  1493
#
#      greedy     CVRP
# 0     32.85    25.77
# 1     61.86    43.84
# 2     94.79    69.30
# 3    130.34    77.28
# 4    166.11    96.21
# ..      ...      ...
# 65  1569.48   884.68
# 66  1829.54  1031.37
# 67  2086.51  1156.39
# 68  2221.94  1243.66
# 69  2440.34  1362.49
#
# [70 rows x 8 columns]
# repeat: 2
# num_candidates=96
# CVRP_distance: 187.72
# row-major sorting: 282
# LAP_distance: 239
# greedy_optimized_distance: 283.22
# num_candidates=192
# CVRP_distance: 328.23
# row-major sorting: 533
# LAP_distance: 429
# greedy_optimized_distance: 548.83
# num_candidates=288
# CVRP_distance: 492.08
# row-major sorting: 788
# LAP_distance: 624
# greedy_optimized_distance: 816.45
# num_candidates=384
# CVRP_distance: 635.47
# row-major sorting: 998
# LAP_distance: 795
# greedy_optimized_distance: 1086.25
# num_candidates=480
# CVRP_distance: 766.79
# row-major sorting: 1237
# LAP_distance: 916
# greedy_optimized_distance: 1336.82
# num_candidates=576
# CVRP_distance: 914.47
# row-major sorting: 1450
# LAP_distance: 1051
# greedy_optimized_distance: 1587.13
# num_candidates=672
# CVRP_distance: 1028.94
# row-major sorting: 1608
# LAP_distance: 1240
# greedy_optimized_distance: 1824.75
# num_candidates=768
# CVRP_distance: 1134.79
# row-major sorting: 1769
# LAP_distance: 1316
# greedy_optimized_distance: 2058.48
# num_candidates=864
# CVRP_distance: 1258.06
# row-major sorting: 1915
# LAP_distance: 1412
# greedy_optimized_distance: 2244.04
# num_candidates=960
# CVRP_distance: 1352.16
# row-major sorting: 2056
# LAP_distance: 1534
# greedy_optimized_distance: 2427.15
#    source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0              12           12          12      1                30    28
# 1              12           12          24      1                58    53
# 2              12           12          36      1                94    87
# 3              12           12          48      1               125    99
# 4              12           12          60      1               146   129
# ..            ...          ...         ...    ...               ...   ...
# 75             12           96         576      2              1450  1051
# 76             12           96         672      2              1608  1240
# 77             12           96         768      2              1769  1316
# 78             12           96         864      2              1915  1412
# 79             12           96         960      2              2056  1534
#
#      greedy     CVRP
# 0     32.85    25.77
# 1     61.86    43.84
# 2     94.79    69.30
# 3    130.34    77.28
# 4    166.11    96.21
# ..      ...      ...
# 75  1587.13   914.47
# 76  1824.75  1028.94
# 77  2058.48  1134.79
# 78  2244.04  1258.06
# 79  2427.15  1352.16
#
# [80 rows x 8 columns]
# repeat: 3
# num_candidates=96
# CVRP_distance: 177.94
# row-major sorting: 268
# LAP_distance: 225
# greedy_optimized_distance: 268.4
# num_candidates=192
# CVRP_distance: 318.56
# row-major sorting: 538
# LAP_distance: 410
# greedy_optimized_distance: 551.53
# num_candidates=288
# CVRP_distance: 495.39
# row-major sorting: 813
# LAP_distance: 624
# greedy_optimized_distance: 823.63
# num_candidates=384
# CVRP_distance: 624.8
# row-major sorting: 1011
# LAP_distance: 750
# greedy_optimized_distance: 1064.08
# num_candidates=480
# CVRP_distance: 761.63
# row-major sorting: 1217
# LAP_distance: 910
# greedy_optimized_distance: 1302.04
# num_candidates=576
# CVRP_distance: 904.31
# row-major sorting: 1453
# LAP_distance: 1057
# greedy_optimized_distance: 1605.88
# num_candidates=672
# CVRP_distance: 991.8
# row-major sorting: 1608
# LAP_distance: 1180
# greedy_optimized_distance: 1812.8
# num_candidates=768
# CVRP_distance: 1116.9
# row-major sorting: 1758
# LAP_distance: 1305
# greedy_optimized_distance: 2032.49
# num_candidates=864
# CVRP_distance: 1228.42
# row-major sorting: 1926
# LAP_distance: 1415
# greedy_optimized_distance: 2261.52
# num_candidates=960
# CVRP_distance: 1363.12
# row-major sorting: 2057
# LAP_distance: 1497
# greedy_optimized_distance: 2475.25
#    source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0              12           12          12      1                30    28
# 1              12           12          24      1                58    53
# 2              12           12          36      1                94    87
# 3              12           12          48      1               125    99
# 4              12           12          60      1               146   129
# ..            ...          ...         ...    ...               ...   ...
# 85             12           96         576      3              1453  1057
# 86             12           96         672      3              1608  1180
# 87             12           96         768      3              1758  1305
# 88             12           96         864      3              1926  1415
# 89             12           96         960      3              2057  1497
#
#      greedy     CVRP
# 0     32.85    25.77
# 1     61.86    43.84
# 2     94.79    69.30
# 3    130.34    77.28
# 4    166.11    96.21
# ..      ...      ...
# 85  1605.88   904.31
# 86  1812.80   991.80
# 87  2032.49  1116.90
# 88  2261.52  1228.42
# 89  2475.25  1363.12
#
# [90 rows x 8 columns]
# source_dim=12, dest_dim=384
# repeat: 1
# num_candidates=384
# CVRP_distance: 737.58
# row-major sorting: 1103
# LAP_distance: 914
# greedy_optimized_distance: 1094.43
# num_candidates=768
# CVRP_distance: 1375.51
# row-major sorting: 2188
# LAP_distance: 1713
# greedy_optimized_distance: 2212.19
# num_candidates=1152
# CVRP_distance: 1995.8
# row-major sorting: 3234
# LAP_distance: 2452
# greedy_optimized_distance: 3266.73
# num_candidates=1536
# CVRP_distance: 2625.18
# row-major sorting: 4248
# LAP_distance: 3147
# greedy_optimized_distance: 4351.59
# num_candidates=1920
# CVRP_distance: 3271.9
# row-major sorting: 5253
# LAP_distance: 3615
# greedy_optimized_distance: 5342.26
# num_candidates=2304
# CVRP_distance: 3902.22
# row-major sorting: 6210
# LAP_distance: 4302
# greedy_optimized_distance: 6243.0
# num_candidates=2688
# CVRP_distance: 4513.54
# row-major sorting: 7333
# LAP_distance: 4822
# greedy_optimized_distance: 7226.34
# num_candidates=3072
# CVRP_distance: 5031.86
# row-major sorting: 8408
# LAP_distance: 5307
# greedy_optimized_distance: 8107.83
# num_candidates=3456
# CVRP_distance: 5669.64
# row-major sorting: 9653
# LAP_distance: 5814
# greedy_optimized_distance: 9090.54
# num_candidates=3840
# CVRP_distance: 6200.38
# row-major sorting: 10932
# LAP_distance: 6179
# greedy_optimized_distance: 9708.67
#    source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0              12           12          12      1                30    28
# 1              12           12          24      1                58    53
# 2              12           12          36      1                94    87
# 3              12           12          48      1               125    99
# 4              12           12          60      1               146   129
# ..            ...          ...         ...    ...               ...   ...
# 95             12          384        2304      1              6210  4302
# 96             12          384        2688      1              7333  4822
# 97             12          384        3072      1              8408  5307
# 98             12          384        3456      1              9653  5814
# 99             12          384        3840      1             10932  6179
#
#      greedy     CVRP
# 0     32.85    25.77
# 1     61.86    43.84
# 2     94.79    69.30
# 3    130.34    77.28
# 4    166.11    96.21
# ..      ...      ...
# 95  6243.00  3902.22
# 96  7226.34  4513.54
# 97  8107.83  5031.86
# 98  9090.54  5669.64
# 99  9708.67  6200.38
#
# [100 rows x 8 columns]
# repeat: 2
# num_candidates=384
# CVRP_distance: 764.22
# row-major sorting: 1134
# LAP_distance: 957
# greedy_optimized_distance: 1135.89
# num_candidates=768
# CVRP_distance: 1392.58
# row-major sorting: 2176
# LAP_distance: 1720
# greedy_optimized_distance: 2198.66
# num_candidates=1152
# CVRP_distance: 1975.13
# row-major sorting: 3219
# LAP_distance: 2424
# greedy_optimized_distance: 3248.95
# num_candidates=1536
# CVRP_distance: 2619.76
# row-major sorting: 4271
# LAP_distance: 3075
# greedy_optimized_distance: 4336.5
# num_candidates=1920
# CVRP_distance: 3248.99
# row-major sorting: 5268
# LAP_distance: 3696
# greedy_optimized_distance: 5360.61
# num_candidates=2304
# CVRP_distance: 3828.47
# row-major sorting: 6319
# LAP_distance: 4267
# greedy_optimized_distance: 6307.6
# num_candidates=2688
# CVRP_distance: 4593.61
# row-major sorting: 7423
# LAP_distance: 4892
# greedy_optimized_distance: 7271.58
# num_candidates=3072
# CVRP_distance: 5099.85
# row-major sorting: 8588
# LAP_distance: 5297
# greedy_optimized_distance: 8134.09
# num_candidates=3456
# CVRP_distance: 5608.65
# row-major sorting: 9725
# LAP_distance: 5817
# greedy_optimized_distance: 9018.88
# num_candidates=3840
# CVRP_distance: 6148.45
# row-major sorting: 10976
# LAP_distance: 6130
# greedy_optimized_distance: 9698.42
#     source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0               12           12          12      1                30    28
# 1               12           12          24      1                58    53
# 2               12           12          36      1                94    87
# 3               12           12          48      1               125    99
# 4               12           12          60      1               146   129
# ..             ...          ...         ...    ...               ...   ...
# 105             12          384        2304      2              6319  4267
# 106             12          384        2688      2              7423  4892
# 107             12          384        3072      2              8588  5297
# 108             12          384        3456      2              9725  5817
# 109             12          384        3840      2             10976  6130
#
#       greedy     CVRP
# 0      32.85    25.77
# 1      61.86    43.84
# 2      94.79    69.30
# 3     130.34    77.28
# 4     166.11    96.21
# ..       ...      ...
# 105  6307.60  3828.47
# 106  7271.58  4593.61
# 107  8134.09  5099.85
# 108  9018.88  5608.65
# 109  9698.42  6148.45
#
# [110 rows x 8 columns]
# repeat: 3
# num_candidates=384
# CVRP_distance: 727.59
# row-major sorting: 1111
# LAP_distance: 923
# greedy_optimized_distance: 1101.17
# num_candidates=768
# CVRP_distance: 1413.39
# row-major sorting: 2235
# LAP_distance: 1736
# greedy_optimized_distance: 2264.4
# num_candidates=1152
# CVRP_distance: 2023.52
# row-major sorting: 3227
# LAP_distance: 2429
# greedy_optimized_distance: 3273.21
# num_candidates=1536
# CVRP_distance: 2577.63
# row-major sorting: 4209
# LAP_distance: 3091
# greedy_optimized_distance: 4279.12
# num_candidates=1920
# CVRP_distance: 3254.12
# row-major sorting: 5254
# LAP_distance: 3730
# greedy_optimized_distance: 5316.57
# num_candidates=2304
# CVRP_distance: 3940.89
# row-major sorting: 6335
# LAP_distance: 4266
# greedy_optimized_distance: 6306.17
# num_candidates=2688
# CVRP_distance: 4605.01
# row-major sorting: 7452
# LAP_distance: 4923
# greedy_optimized_distance: 7358.72
# num_candidates=3072
# CVRP_distance: 5069.6
# row-major sorting: 8446
# LAP_distance: 5305
# greedy_optimized_distance: 8079.65
# num_candidates=3456
# CVRP_distance: 5668.28
# row-major sorting: 9733
# LAP_distance: 5788
# greedy_optimized_distance: 9020.29
# num_candidates=3840
# CVRP_distance: 6191.18
# row-major sorting: 10939
# LAP_distance: 6137
# greedy_optimized_distance: 9705.55
#     source_labware dest_labware num_samples repeat row-major sorting   LAP  \
# 0               12           12          12      1                30    28
# 1               12           12          24      1                58    53
# 2               12           12          36      1                94    87
# 3               12           12          48      1               125    99
# 4               12           12          60      1               146   129
# ..             ...          ...         ...    ...               ...   ...
# 115             12          384        2304      3              6335  4266
# 116             12          384        2688      3              7452  4923
# 117             12          384        3072      3              8446  5305
# 118             12          384        3456      3              9733  5788
# 119             12          384        3840      3             10939  6137
#
#       greedy     CVRP
# 0      32.85    25.77
# 1      61.86    43.84
# 2      94.79    69.30
# 3     130.34    77.28
# 4     166.11    96.21
# ..       ...      ...
# 115  6306.17  3940.89
# 116  7358.72  4605.01
# 117  8079.65  5069.60
# 118  9020.29  5668.28
# 119  9705.55  6191.18
#
# [120 rows x 8 columns]
# source_dim=24, dest_dim=12
# repeat: 1
# num_candidates=12
# CVRP_distance: 25.81
# row-major sorting: 29
# LAP_distance: 29
# greedy_optimized_distance: 31.28
# num_candidates=24
# CVRP_distance: 51.69
# row-major sorting: 59
# LAP_distance: 56
# greedy_optimized_distance: 62.64
# num_candidates=36
# CVRP_distance: 63.84
# row-major sorting: 91
# LAP_distance: 79
# greedy_optimized_distance: 101.17
# num_candidates=48
# CVRP_distance: 87.78
# row-major sorting: 119
# LAP_distance: 111
# greedy_optimized_distance: 133.19
# num_candidates=60
# CVRP_distance: 102.56
# row-major sorting: 155
# LAP_distance: 128
# greedy_optimized_distance: 167.21
# num_candidates=72
# CVRP_distance: 121.4
# row-major sorting: 187
# LAP_distance: 157
# greedy_optimized_distance: 216.34
# num_candidates=84
# CVRP_distance: 136.41
# row-major sorting: 214
# LAP_distance: 183
# greedy_optimized_distance: 225.09
# num_candidates=96
# CVRP_distance: 146.97
# row-major sorting: 230
# LAP_distance: 195
# greedy_optimized_distance: 253.66
# num_candidates=108
# CVRP_distance: 171.27
# row-major sorting: 267
# LAP_distance: 217
# greedy_optimized_distance: 286.24
# num_candidates=120
# CVRP_distance: 195.23
# row-major sorting: 300
# LAP_distance: 255
# greedy_optimized_distance: 330.2
#     source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0               12           12          12      1                30   28
# 1               12           12          24      1                58   53
# 2               12           12          36      1                94   87
# 3               12           12          48      1               125   99
# 4               12           12          60      1               146  129
# ..             ...          ...         ...    ...               ...  ...
# 125             24           12          72      1               187  157
# 126             24           12          84      1               214  183
# 127             24           12          96      1               230  195
# 128             24           12         108      1               267  217
# 129             24           12         120      1               300  255
#
#      greedy    CVRP
# 0     32.85   25.77
# 1     61.86   43.84
# 2     94.79   69.30
# 3    130.34   77.28
# 4    166.11   96.21
# ..      ...     ...
# 125  216.34  121.40
# 126  225.09  136.41
# 127  253.66  146.97
# 128  286.24  171.27
# 129  330.20  195.23
#
# [130 rows x 8 columns]
# repeat: 2
# num_candidates=12
# CVRP_distance: 28.25
# row-major sorting: 30
# LAP_distance: 31
# greedy_optimized_distance: 32.3
# num_candidates=24
# CVRP_distance: 49.01
# row-major sorting: 57
# LAP_distance: 57
# greedy_optimized_distance: 64.1
# num_candidates=36
# CVRP_distance: 67.13
# row-major sorting: 88
# LAP_distance: 83
# greedy_optimized_distance: 97.95
# num_candidates=48
# CVRP_distance: 84.15
# row-major sorting: 116
# LAP_distance: 112
# greedy_optimized_distance: 130.15
# num_candidates=60
# CVRP_distance: 103.59
# row-major sorting: 142
# LAP_distance: 133
# greedy_optimized_distance: 159.37
# num_candidates=72
# CVRP_distance: 125.25
# row-major sorting: 183
# LAP_distance: 160
# greedy_optimized_distance: 205.76
# num_candidates=84
# CVRP_distance: 141.18
# row-major sorting: 216
# LAP_distance: 183
# greedy_optimized_distance: 233.47
# num_candidates=96
# CVRP_distance: 152.16
# row-major sorting: 236
# LAP_distance: 196
# greedy_optimized_distance: 262.74
# num_candidates=108
# CVRP_distance: 176.55
# row-major sorting: 267
# LAP_distance: 235
# greedy_optimized_distance: 294.87
# num_candidates=120
# CVRP_distance: 191.72
# row-major sorting: 296
# LAP_distance: 249
# greedy_optimized_distance: 325.11
#     source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0               12           12          12      1                30   28
# 1               12           12          24      1                58   53
# 2               12           12          36      1                94   87
# 3               12           12          48      1               125   99
# 4               12           12          60      1               146  129
# ..             ...          ...         ...    ...               ...  ...
# 135             24           12          72      2               183  160
# 136             24           12          84      2               216  183
# 137             24           12          96      2               236  196
# 138             24           12         108      2               267  235
# 139             24           12         120      2               296  249
#
#      greedy    CVRP
# 0     32.85   25.77
# 1     61.86   43.84
# 2     94.79   69.30
# 3    130.34   77.28
# 4    166.11   96.21
# ..      ...     ...
# 135  205.76  125.25
# 136  233.47  141.18
# 137  262.74  152.16
# 138  294.87  176.55
# 139  325.11  191.72
#
# [140 rows x 8 columns]
# repeat: 3
# num_candidates=12
# CVRP_distance: 30.57
# row-major sorting: 31
# LAP_distance: 34
# greedy_optimized_distance: 31.98
# num_candidates=24
# CVRP_distance: 49.45
# row-major sorting: 60
# LAP_distance: 60
# greedy_optimized_distance: 64.75
# num_candidates=36
# CVRP_distance: 73.69
# row-major sorting: 97
# LAP_distance: 91
# greedy_optimized_distance: 106.15
# num_candidates=48
# CVRP_distance: 85.28
# row-major sorting: 111
# LAP_distance: 105
# greedy_optimized_distance: 133.53
# num_candidates=60
# CVRP_distance: 105.01
# row-major sorting: 150
# LAP_distance: 137
# greedy_optimized_distance: 162.02
# num_candidates=72
# CVRP_distance: 125.22
# row-major sorting: 184
# LAP_distance: 158
# greedy_optimized_distance: 204.3
# num_candidates=84
# CVRP_distance: 147.06
# row-major sorting: 216
# LAP_distance: 184
# greedy_optimized_distance: 230.52
# num_candidates=96
# CVRP_distance: 162.25
# row-major sorting: 244
# LAP_distance: 218
# greedy_optimized_distance: 277.76
# num_candidates=108
# CVRP_distance: 180.46
# row-major sorting: 269
# LAP_distance: 239
# greedy_optimized_distance: 310.68
# num_candidates=120
# CVRP_distance: 182.09
# row-major sorting: 301
# LAP_distance: 222
# greedy_optimized_distance: 322.36
#     source_labware dest_labware num_samples repeat row-major sorting  LAP  \
# 0               12           12          12      1                30   28
# 1               12           12          24      1                58   53
# 2               12           12          36      1                94   87
# 3               12           12          48      1               125   99
# 4               12           12          60      1               146  129
# ..             ...          ...         ...    ...               ...  ...
# 145             24           12          72      3               184  158
# 146             24           12          84      3               216  184
# 147             24           12          96      3               244  218
# 148             24           12         108      3               269  239
# 149             24           12         120      3               301  222
#
#      greedy    CVRP
# 0     32.85   25.77
# 1     61.86   43.84
# 2     94.79   69.30
# 3    130.34   77.28
# 4    166.11   96.21
# ..      ...     ...
# 145  204.30  125.22
# 146  230.52  147.06
# 147  277.76  162.25
# 148  310.68  180.46
# 149  322.36  182.09
#
# [150 rows x 8 columns]
# source_dim=24, dest_dim=24
# repeat: 1
# num_candidates=24
# CVRP_distance: 50.86
# row-major sorting: 61
# LAP_distance: 58
# greedy_optimized_distance: 66.05
# num_candidates=48
# CVRP_distance: 87.08
# row-major sorting: 125
# LAP_distance: 112
# greedy_optimized_distance: 137.52
# num_candidates=72
# CVRP_distance: 135.89
# row-major sorting: 192
# LAP_distance: 165
# greedy_optimized_distance: 209.86
# num_candidates=96

# %%
# plot the results
for labware_combination in labware_combinations:
    source = labware_combination[0]
    dest = labware_combination[1]
    df_choosen = df[(df['source_labware'] == source) & (df['dest_labware'] == dest)]
    # compute the mean and std of the unoptimized, rowwise, greedy and VRP
    df_choosen_mean = df_choosen.groupby(['num_samples']).mean().reset_index()
    df_choosen_std = df_choosen.groupby(['num_samples']).std().reset_index()
    # plot the results
    plt.figure(figsize=(4, 3),dpi=200,clear=True)
    plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['row-major sorting'], yerr=df_choosen_std['row-major sorting'], label='row-major sorting', fmt='o-', capsize=5)
    plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['LAP'], yerr=df_choosen_std['LAP'], label='LAP', fmt='o-', capsize=5)
    plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['greedy'], yerr=df_choosen_std['greedy'], label='greedy', fmt='o-', capsize=5)
    plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['CVRP'], yerr=df_choosen_std['CVRP'], label='CVRP', fmt='o-', capsize=5)
    plt.title(f' {source}-well plate --> {dest}-well plate', fontsize=15)
    plt.xlabel('Number of liquid transfers', fontsize=12)
    plt.ylabel('Computed execution time (s)', fontsize=12)
    # tick labels size
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.locator_params(nbins=7)
    plt.legend(frameon=False)
    #plt.tight_layout()
    plt.show()

# %%
# optimization for 1536-well plates
np.random.seed(0)
for labware_combination in labware_combinations: 

    source_dim = 1536
    dest_dim = 1536
    print(f'source_dim={source_dim}, dest_dim={dest_dim}')
    # repeat the experiment 3 times
    for r in range(3):
        print('repeat:',r+1)
        stats = []
        for i in range(1, 11, 2):

            num_candidates = dest_dim * i 
            num_candidates = int(num_candidates)
            print(f'num_candidates={num_candidates}')
            a = random_task_generation(source_dim,dest_dim,num_candidates)
            jobs = np.argwhere(a)
            D_S = calculate_D(a.shape[0])
            D_D = calculate_D(a.shape[1])
            S, E, volumes = calculate_S_E(a)

            # calculate distance matrix for CVRP
            D_prime = calculate_D_prime(D_S, D_D, S, E, volumes, 1, 100, 1, 100)
            # VRP solver
            if num_candidates <7000:
                CVRP_distance, CVRP_recorder = CVRP_solver(np.round(D_prime * 100).astype(np.int64), solving_time=60)
            else:
                CVRP_distance, CVRP_recorder = CVRP_solver(np.round(D_prime * 100).astype(np.int64), solving_time=120)
            # bring the VRP_distance to the original scale
            CVRP_distance = CVRP_distance / 100
            print(f'CVRP_distance: {CVRP_distance}')

            # calculate the cost of the row-major sorting
            # create a sequence of tasks
            tasks = np.array(range(jobs.shape[0]))
            tasks = tasks+1
            # if tasks.shape[0] %8 != 0, pad with -1
            if tasks.shape[0] %8 != 0:
                tasks = np.pad(tasks, (0, 8-tasks.shape[0]%8), 'constant', constant_values=-1)
            rms_seuqnece = tasks.reshape(-1, 8)
            t = calculate_X(rms_seuqnece)
            d = np.round(D_prime * 100)
            rms_distance = np.trace(np.dot(t.T, d))/100
            rms_distance = int(rms_distance)
            print(f'row-major sorting: {rms_distance}')
            
            # calculate the cost of the LAP
            index_matrix = np.zeros((source_dim,dest_dim))
            for j in range(jobs.shape[0]):
                index_matrix[jobs[j, 0], jobs[j, 1]] = j+1
            LAP_sequence = LAP(index_matrix)
            if LAP_sequence.shape[0] %8 != 0:
                LAP_sequence = np.pad(LAP_sequence, (0, 8-LAP_sequence.shape[0]%8), 'constant', constant_values=-1)
            LAP_sequence = LAP_sequence.reshape(-1, 8)
            t = calculate_X(LAP_sequence)
            LAP_distance = np.trace(np.dot(t.T, d))/100
            # change non_optimized_distance to integer
            LAP_distance = int(LAP_distance)
            print(f'LAP_distance: {LAP_distance}')

            # calculate the cost of the greedy optimized sequence
            greedy_optimized_sequence = greedy(jobs, d[1:,1:])
            if greedy_optimized_sequence.shape[0] %8 != 0:
                greedy_optimized_sequence = np.pad(greedy_optimized_sequence, (0, 8-greedy_optimized_sequence.shape[0]%8), 'constant', constant_values=-1)
            greedy_optimized_sequence = greedy_optimized_sequence.reshape(-1, 8)
            t = calculate_X(greedy_optimized_sequence)
            greedy_optimized_distance = np.trace(np.dot(t.T, d))/100
            print(f'greedy_optimized_distance: {greedy_optimized_distance}')
            # append the results to the df
            stats.append([source_dim, dest_dim, num_candidates, r+1, rms_distance, LAP_distance, greedy_optimized_distance, CVRP_distance])
        # convert the stats to the dataframe
        stats = pd.DataFrame(stats, columns=['source_labware', 'dest_labware', 'num_samples', 'repeat', 'row-major sorting','LAP', 'greedy','CVRP'])
        # append the stats to the df
        df = pd.concat([df, stats], ignore_index=True)
        print(df)
# save the results to a csv file
df.to_csv('1536_results.csv', index=False)

# %%
source = 1536
dest = 1536
df_choosen = df[(df['source_labware'] == source) & (df['dest_labware'] == dest)]
# compute the mean and std of the unoptimized, rowwise, greedy and VRP
df_choosen_mean = df_choosen.groupby(['num_samples']).mean().reset_index()
df_choosen_std = df_choosen.groupby(['num_samples']).std().reset_index()
# plot the results
plt.figure(figsize=(4, 3),dpi=200,clear=True)
plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['row-major sorting'], yerr=df_choosen_std['row-major sorting'], label='row-major sorting', fmt='o-', capsize=5)
plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['LAP'], yerr=df_choosen_std['LAP'], label='LAP', fmt='o-', capsize=5)
plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['greedy'], yerr=df_choosen_std['greedy'], label='greedy', fmt='o-', capsize=5)
plt.errorbar(df_choosen_mean['num_samples'], df_choosen_mean['CVRP'], yerr=df_choosen_std['CVRP'], label='CVRP', fmt='o-', capsize=5)
plt.title(f' {source}-well plate --> {dest}-well plate', fontsize=15)
plt.xlabel('Number of liquid transfers', fontsize=12)
plt.ylabel('Computed execution time (s)', fontsize=12)
# tick labels size
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=12)
plt.locator_params(nbins=7)
plt.legend(frameon=False)
#plt.tight_layout()
plt.show()
